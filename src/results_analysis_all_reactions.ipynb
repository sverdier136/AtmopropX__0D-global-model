# %% [markdown]
# All reactions

# %%
import json
import numpy as np

# %%
log_file_path = '../logs/all_reaction_prf.json'
#log_file_path='../logs/test_simu.json'
tracked_variables = {}
with open(log_file_path, 'r') as file:
    tracked_variables = json.load(file)

# %%
var_list = list(tracked_variables.keys())
print(var_list)
print(len(tracked_variables['R_ind']))
print(len(tracked_variables['e_density']))
print(tracked_variables['R_ind'][-1]) #0.82 pour PRF, 0.908 pour constant current
# Out:
# ['xenon_leaving', 'density_change_flux_to_walls_and_through_grids0', 'density_change_flux_to_walls_and_through_grids1', 'density_change_flux_to_walls_and_through_grids2', 'energy_change_flux_to_walls_and_through_grids0', 'energy_change_flux_to_walls_and_through_grids1', 'energy_change_flux_to_walls_and_through_grids2', 'density_change_gas_injection0', 'density_change_gas_injection1', 'density_change_gas_injection2', 'energy_change_gas_injection0', 'energy_change_gas_injection1', 'energy_change_gas_injection2', 'Kiz', 'reaction_speed', 'density_change_ionisation0', 'density_change_ionisation1', 'density_change_ionisation2', 'energy_change_ionisation0', 'energy_change_ionisation1', 'energy_change_ionisation2', 'Kexc', 'energy_change_excitation', 'energy_change_elastic_collision', 'energy_change_thermic_diffusion0', 'energy_change_thermic_diffusion1', 'energy_change_thermic_diffusion2', 'energy_change_inelastic_collision0', 'energy_change_inelastic_collision1', 'energy_change_inelastic_collision2', 'collision_frequencies0', 'collision_frequencies1', 'collision_frequencies2', 'R_ind', 'R_ind_a', 'R_ind_b', 'power_transfer_efficiency', 'absorbed_power', 'power', 'dy_energy_0_atom', 'dy_energy_1_atom', 'dy_energy_2_atom', 'time', 'e_density', 'Xe_density', 'Xe+_density', 'temperature_0_atom', 'temperature_1_atom', 'temperature_2_atom', 'dy_e_density', 'dy_Xe_density', 'dy_Xe+_density', 'dy_temperature_0_atom', 'dy_temperature_1_atom', 'dy_temperature_2_atom', 'energy_0_atom', 'energy_1_atom', 'energy_2_atom', 'h_L', 'h_R', 'total_ion_thrust', 'total_neutral_thrust', 'total_thrust', 'u_B', 'ion_current']
# 527
# 527
# 1.2937343241022603

# %%
import matplotlib.pyplot as plt

def plot_variables(var_list1, var_list2):
    """
    Plots the evolution of variables from tracked_variables with 'time' on the x-axis.
    The first list of variables is plotted on the primary y-axis, and the second list on a secondary y-axis.

    Parameters:
    var_list1 (list): List of variable names to plot on the primary y-axis.
    var_list2 (list): List of variable names to plot on the secondary y-axis.
    """
    time = tracked_variables['time']
    
    fig, ax1 = plt.subplots()

    # Plot variables from var_list1 on the primary y-axis
    for var in var_list1:
        if var in tracked_variables:
            ax1.plot(time, tracked_variables[var], label=var)
    ax1.set_xlabel('Time')
    ax1.set_ylabel(str(var_list1))
    ax1.grid()

    # #Vérification du temps de relaxation:
    # tau=7.9e-3
    # T_init=3
    # L=[tangente(t,T_init,tau) for t in time]

    # Create a secondary y-axis
    ax2 = ax1.twinx()
    for var in var_list2:
        if var in tracked_variables:
            ax2.plot(time, tracked_variables[var], linestyle='--', label=var)
    # ax2.plot(L,label="tangente à l'orgine")
    ax2.set_ylabel(str(var_list2))

    ax2.legend(loc='best')

    # x_vert=7.9e-3
    # plt.axvline(x_vert, color='r', linestyle='--')

    lines_2, labels_2 = ax2.get_legend_handles_labels()
    lines_1, labels_1 = ax1.get_legend_handles_labels()
    ax2.legend(lines_2 + lines_1, labels_2 + labels_1, loc='best')

    plt.title('Evolution of Variables')
    plt.show()

# %%
print(tracked_variables['temperature_0_atom'][-1]) #2.7, ça part à 1.5e6
# Out:
# 9.999999961183844e-06

# %%
plot_variables(['e_density'], [])
plot_variables(['N_density'], [])
#plot_variables(['dy_e_density'], ['dy_Xe_density', 'dy_Xe+_density'])
plot_variables(['N2_density'],[])
plot_variables(['O_density'],[])
plot_variables(['O2_density'],[])
#plot_variables(['e_density'],['Xe+_density'])
# Out:
# C:\Users\verdi\AppData\Local\Temp\ipykernel_23884\1856211196.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(loc='best')

# %%
plot_variables(["temperature_0_atom"], ["temperature_1_atom", "temperature_2_atom"])
#plot_variables(["dy_temperature_0_atom"], ["dy_temperature_1_atom", "dy_temperature_2_atom"])
plot_variables(["temperature_0_atom"],[])
plot_variables(["temperature_1_atom"],[])
# Out:
# C:\Users\verdi\AppData\Local\Temp\ipykernel_23884\1856211196.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(loc='best')

# %% [markdown]
# Asymptote horizontale à la température des électrons = 0.054 eV d'après la simu json. Donc cohérent avec valeur théorique.

# %%
plot_variables(['energy_0_atom'], ['energy_1_atom', 'energy_2_atom'])
plot_variables(['dy_energy_0_atom'], ['dy_energy_1_atom', 'dy_energy_2_atom'])

# %%
plot_variables(['dy_energy_0_gas_injection', 'dy_energy_1_gas_injection'], [])
plot_variables(['dy_energy_0_before_heating', 'dy_energy_1_before_heating'], [])
# Out:
# C:\Users\verdi\AppData\Local\Temp\ipykernel_23884\1856211196.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(loc='best')

# %%
plot_variables(["eps_p_real"], ["eps_p_imag"])
# Out:
# C:\Users\verdi\AppData\Local\Temp\ipykernel_23884\1856211196.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(loc='best')

# %%
plot_variables(["R_ind_a"], ["R_ind_b"])
# Out:
# C:\Users\verdi\AppData\Local\Temp\ipykernel_23884\1856211196.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(loc='best')

# %%
plot_variables(["R_ind"], [])
# Out:
# C:\Users\verdi\AppData\Local\Temp\ipykernel_23884\1856211196.py:37: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax2.legend(loc='best')
